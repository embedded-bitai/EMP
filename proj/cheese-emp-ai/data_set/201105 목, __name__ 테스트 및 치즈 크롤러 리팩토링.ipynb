# %%
# module.py

def hello():
    print("Hello!")
    
print(__name__)
# Out:
# __main__

# %% [markdown]
# ## 테스트

# %%
import module

print(__name__)
module.hello()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-5-e125a3db156c> in <module>
# ----> 1 import module
#       2
#       3 print(__name__)
#       4 module.hello()
#
# ModuleNotFoundError: No module named 'module'

# %%
# 파일명 지정하기가 번거로워서 VS Code에서 테스트해보기로 함

# %%
help(str)
# Out:
# Help on class str in module builtins:
#
# class str(object)
#  |  str(object='') -> str
#  |  str(bytes_or_buffer[, encoding[, errors]]) -> str
#  |
#  |  Create a new string object from the given object. If encoding or
#  |  errors is specified, then the object must expose a data buffer
#  |  that will be decoded using the given encoding and error handler.
#  |  Otherwise, returns the result of object.__str__() (if defined)
#  |  or repr(object).
#  |  encoding defaults to sys.getdefaultencoding().
#  |  errors defaults to 'strict'.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __format__(self, format_spec, /)
#  |      Return a formatted version of the string as described by format_spec.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
# ...

# %%
help(repr)
# Out:
# Help on built-in function repr in module builtins:
#
# repr(obj, /)
#     Return the canonical string representation of the object.
#
#     For many object types, including most builtins, eval(repr(obj)) == obj.

# %%
import time
import math

repr(3)
repr({1,2})
repr(time)
repr(math)
# Out:
# "<module 'math' from '/home/bitai/anaconda3/lib/python3.7/lib-dynload/math.cpython-37m-x86_64-linux-gnu.so'>"

# %%
class A:
    def __str__(self):
        return 'str wandoo'
    
    def __repr__(self):
        return 'repr wandoo'
    
a = A()
    
str(a)
# Out:
# 'str wandoo'

# %%
class A:
    def __repr__(self):
        return str(id(self))

# %%
a = A()
a
# Out:
# 140350066864272

# %%
class NewInt(A, int):
    pass

# %%
n = NewInt(5)
n + 5
# Out:
# 10

# %%
str(n)
# Out:
# '5'

# %%
repr(n)
# Out:
# '140350407769536'

# %%
# URL = 'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=40725&page={}'

URL = 'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=40725&page={}'

# %%
for n in range (1, 3):
    url = URL.format(n+1)
    
    print(url)
# Out:
# https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=40725&page=2
# https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=40725&page=3

# %%
test1 = 500

test1
# Out:
# 500

# %%
num
# Out:
# 3

# %%
# 55222 38186 32309 7388 5765 40724 52606 5869 47724 40725
url_list = [55222, 38186, 32309, 7388, 5765, 40724, 52606, 5869, 47724, 40725]

url_list
# Out:
# [55222, 38186, 32309, 7388, 5765, 40724, 52606, 5869, 47724, 40725]

# %%
for url_element in url_list:
    print(url_element)
# Out:
# 55222
# 38186
# 32309
# 7388
# 5765
# 40724
# 52606
# 5869
# 47724
# 40725

# %%
page_num = 0
# URL_2 = f'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno={url_list}&page={page_num}'


# 2 ~ 10 페이지의 내용을 크롤링 한다.
for page_num in range (2, len(url_list) + 1):
    
    for url_element in url_list:
        
        URL_2 = f'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno={url_element}&page={page_num}'
        page_num = page_num + 1
        
        #print("======dim 2: ", url_element)
        print("dim 1 URL: ", URL_2)
        print("=====222")
    
    # page_num = page_num + 1
    #print("===dim 1, page_num:", page_num)
    #print(" ")
    #print("===dim 1, url: " + URL_2)
    #print(" ")

print("=== 최종", URL_2)
# Out:
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=2
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=38186&page=3
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=32309&page=4
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=7388&page=5
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=5765&page=6
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=40724&page=7
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=52606&page=8
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=5869&page=9
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=47724&page=10
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=40725&page=11
# ...

# %%
page_num = 2
# URL_2 = f'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno={url_list}&page={page_num}'


# 2 ~ 10 페이지의 내용을 크롤링 한다.
# for page_num in range (2, len(url_list) + 1):
    
for url_element in url_list:

    for p in len(page_num):
        page_num = page_num + 1
        
        URL_2 = f'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno={url_element}&page={page_num}'

    #print("======dim 2: ", url_element)
        print("dim 1 URL: ", URL_2)
        print("=====222")

# page_num = page_num + 1
#print("===dim 1, page_num:", page_num)
#print(" ")
#print("===dim 1, url: " + URL_2)
#print(" ")

# print("=== 최종", URL_2)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-83fdafbc077e> in <module>
#       8 for url_element in url_list:
#       9
# ---> 10     for p in len(page_num):
#      11         page_num = page_num + 1
#      12
#
# TypeError: object of type 'int' has no len()

# %%
# 55222 38186 32309 7388 5765 40724 52606 5869 47724 40725

page_num = 0
# URL_2 = f'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno={url_list}&page={page_num}'


# 2 ~ 10 페이지의 내용을 크롤링 한다.
# for page_num in range (2, len(url_list)-5):
for url_element in url_list:
    
    for page_num in range(2, 11):
        URL_2 = f'https://www.kurly.com/shop/goods/goods_review_list.php?goodsno={url_element}&page={page_num}'
        # page_num = page_num + 1


        #print("======dim 2: ", url_element)
        print("dim 1 URL: ", URL_2)
        print("=====222")

# print("=== 최종", URL_2)
# Out:
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=2
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=3
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=4
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=5
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=6
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=7
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=8
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=9
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=55222&page=10
# =====222
# dim 1 URL:  https://www.kurly.com/shop/goods/goods_review_list.php?goodsno=38186&page=2
# ...
