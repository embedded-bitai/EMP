# %%
import pandas as pd

# %%
cheese_data_frame = pd.read_csv(
    '/home/bitai/Documents/EMP_Team/EMP_Main/Ai/cheese_flask_proj/com_cheese_api/cop/itm/cheese/data/cheese_data.csv',
    sep=','
)

# %%
cheese_data_frame
# Out:
#     Unnamed: 0  ranking cheese_id   brand           name country  \
# 0            1        1        p1  벨지오이오소         부라타 치즈    이탈리아
# 1            2        2        p2    프란시아        모짜렐라 카우    이탈리아
# 2            3        3        p3     브렐렛        모짜렐라 카우    이탈리아
# 3            4        4        p4    카스텔로      덴마크 브리 치즈     덴마크
# 4            5        5        p5     브리미           보코치니    이탈리아
# ..         ...      ...       ...     ...            ...     ...
# 66          83       67       p67     사토리       올드 월드 체다      미국
# 67          84       68       p68     라퀘유         푸름 당베르     프랑스
# 68          85       69       p69   그랑도르즈      베이크드 까망베르     프랑스
# 69          86       70       p70  퀘소로시난테  만체고 블랙 트러플 치즈     스페인
# 70          88       71       p71     라퀘유        블루 도베르뉴     프랑스
#
#                               matching texture types category    price  \
# 0                       채소, 발사믹식초, 견과류   후레쉬치즈  자연치즈      부라타  14,900원
# ...

# %%
df = cheese_data_frame

# %%
df.drop(df.columns[0], axis=1, inplace=True)

# %%
df
# Out:
#     ranking cheese_id   brand           name country  \
# 0         1        p1  벨지오이오소         부라타 치즈    이탈리아
# 1         2        p2    프란시아        모짜렐라 카우    이탈리아
# 2         3        p3     브렐렛        모짜렐라 카우    이탈리아
# 3         4        p4    카스텔로      덴마크 브리 치즈     덴마크
# 4         5        p5     브리미           보코치니    이탈리아
# ..      ...       ...     ...            ...     ...
# 66       67       p67     사토리       올드 월드 체다      미국
# 67       68       p68     라퀘유         푸름 당베르     프랑스
# 68       69       p69   그랑도르즈      베이크드 까망베르     프랑스
# 69       70       p70  퀘소로시난테  만체고 블랙 트러플 치즈     스페인
# 70       71       p71     라퀘유        블루 도베르뉴     프랑스
#
#                               matching texture types category    price  \
# 0                       채소, 발사믹식초, 견과류   후레쉬치즈  자연치즈      부라타  14,900원
# 1                           토마토,바질,샐러드   후레쉬치즈  자연치즈     모짜렐라   3,870원
# 2                           카프레제, 사퀘테리   후레쉬치즈  자연치즈     모짜렐라   3,990원
# ...

# %%
df2 = df.replace('원', '')

# %%
split = df['price'].str.split("원")
df['price'] = split.str.get(0)
split
# Out:
# 0     [14,900, ]
# 1      [3,870, ]
# 2      [3,990, ]
# 3      [4,165, ]
# 4      [6,800, ]
#          ...
# 66    [11,500, ]
# 67    [12,500, ]
# 68    [11,900, ]
# 69    [12,500, ]
# 70    [10,200, ]
# Name: price, Length: 71, dtype: object

# %%
df
# Out:
#     ranking cheese_id   brand           name country  \
# 0         1        p1  벨지오이오소         부라타 치즈    이탈리아
# 1         2        p2    프란시아        모짜렐라 카우    이탈리아
# 2         3        p3     브렐렛        모짜렐라 카우    이탈리아
# 3         4        p4    카스텔로      덴마크 브리 치즈     덴마크
# 4         5        p5     브리미           보코치니    이탈리아
# ..      ...       ...     ...            ...     ...
# 66       67       p67     사토리       올드 월드 체다      미국
# 67       68       p68     라퀘유         푸름 당베르     프랑스
# 68       69       p69   그랑도르즈      베이크드 까망베르     프랑스
# 69       70       p70  퀘소로시난테  만체고 블랙 트러플 치즈     스페인
# 70       71       p71     라퀘유        블루 도베르뉴     프랑스
#
#                               matching texture types category   price  \
# 0                       채소, 발사믹식초, 견과류   후레쉬치즈  자연치즈      부라타  14,900
# 1                           토마토,바질,샐러드   후레쉬치즈  자연치즈     모짜렐라   3,870
# 2                           카프레제, 사퀘테리   후레쉬치즈  자연치즈     모짜렐라   3,990
# ...

# %%
df2
# Out:
#     ranking cheese_id   brand           name country  \
# 0         1        p1  벨지오이오소         부라타 치즈    이탈리아
# 1         2        p2    프란시아        모짜렐라 카우    이탈리아
# 2         3        p3     브렐렛        모짜렐라 카우    이탈리아
# 3         4        p4    카스텔로      덴마크 브리 치즈     덴마크
# 4         5        p5     브리미           보코치니    이탈리아
# ..      ...       ...     ...            ...     ...
# 66       67       p67     사토리       올드 월드 체다      미국
# 67       68       p68     라퀘유         푸름 당베르     프랑스
# 68       69       p69   그랑도르즈      베이크드 까망베르     프랑스
# 69       70       p70  퀘소로시난테  만체고 블랙 트러플 치즈     스페인
# 70       71       p71     라퀘유        블루 도베르뉴     프랑스
#
#                               matching texture types category price  \
# 0                       채소, 발사믹식초, 견과류   후레쉬치즈  자연치즈      부라타
# 1                           토마토,바질,샐러드   후레쉬치즈  자연치즈     모짜렐라
# 2                           카프레제, 사퀘테리   후레쉬치즈  자연치즈     모짜렐라
# 3                        빵, 꿀, 견과류, 와인   소프트치즈  자연치즈       브리
# ...

# %%
df.drop('country', axis=1, inplace=True)
df.drop('matching', axis=1, inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-33-1f238367ae92> in <module>
# ----> 1 df.drop('country', axis=1, inplace=True)
#       2 df.drop('matching', axis=1, inplace=True)
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ...

# %%
df
# Out:
#     ranking cheese_id   brand           name texture types category   price  \
# 0         1        p1  벨지오이오소         부라타 치즈   후레쉬치즈  자연치즈      부라타  14,900
# 1         2        p2    프란시아        모짜렐라 카우   후레쉬치즈  자연치즈     모짜렐라   3,870
# 2         3        p3     브렐렛        모짜렐라 카우   후레쉬치즈  자연치즈     모짜렐라   3,990
# 3         4        p4    카스텔로      덴마크 브리 치즈   소프트치즈  자연치즈       브리   4,165
# 4         5        p5     브리미           보코치니   후레쉬치즈  자연치즈     모짜렐라   6,800
# ..      ...       ...     ...            ...     ...   ...      ...     ...
# 66       67       p67     사토리       올드 월드 체다    하드치즈  자연치즈       체다  11,500
# 67       68       p68     라퀘유         푸름 당베르    연성치즈  자연치즈     블루치즈  12,500
# 68       69       p69   그랑도르즈      베이크드 까망베르   소프트치즈  자연치즈     까망베르  11,900
# 69       70       p70  퀘소로시난테  만체고 블랙 트러플 치즈    하드치즈  자연치즈      만체고  12,500
# 70       71       p71     라퀘유        블루 도베르뉴  세미하드치즈  자연치즈     블루치즈  10,200
#
#                         content  \
# ...

# %%
df2 = df.replace(',', '')

# %%
df2
# Out:
#     ranking cheese_id   brand           name texture types category   price  \
# 0         1        p1  벨지오이오소         부라타 치즈   후레쉬치즈  자연치즈      부라타  14,900
# 1         2        p2    프란시아        모짜렐라 카우   후레쉬치즈  자연치즈     모짜렐라   3,870
# 2         3        p3     브렐렛        모짜렐라 카우   후레쉬치즈  자연치즈     모짜렐라   3,990
# 3         4        p4    카스텔로      덴마크 브리 치즈   소프트치즈  자연치즈       브리   4,165
# 4         5        p5     브리미           보코치니   후레쉬치즈  자연치즈     모짜렐라   6,800
# ..      ...       ...     ...            ...     ...   ...      ...     ...
# 66       67       p67     사토리       올드 월드 체다    하드치즈  자연치즈       체다  11,500
# 67       68       p68     라퀘유         푸름 당베르    연성치즈  자연치즈     블루치즈  12,500
# 68       69       p69   그랑도르즈      베이크드 까망베르   소프트치즈  자연치즈     까망베르  11,900
# 69       70       p70  퀘소로시난테  만체고 블랙 트러플 치즈    하드치즈  자연치즈      만체고  12,500
# 70       71       p71     라퀘유        블루 도베르뉴  세미하드치즈  자연치즈     블루치즈  10,200
#
#                         content  \
# ...

# %%
s = 'Foo, bar'

# %%
s.replace(',', '')
# Out:
# 'Foo bar'

# %%
def remove_comma(x):
    return x.replace(',', '')

df['price'] = df['price'].apply(remove_comma)

print(df)
print(df.dtypes)
# Out:
#     ranking cheese_id   brand           name texture types category  price  \
# 0         1        p1  벨지오이오소         부라타 치즈   후레쉬치즈  자연치즈      부라타  14900
# 1         2        p2    프란시아        모짜렐라 카우   후레쉬치즈  자연치즈     모짜렐라   3870
# 2         3        p3     브렐렛        모짜렐라 카우   후레쉬치즈  자연치즈     모짜렐라   3990
# 3         4        p4    카스텔로      덴마크 브리 치즈   소프트치즈  자연치즈       브리   4165
# 4         5        p5     브리미           보코치니   후레쉬치즈  자연치즈     모짜렐라   6800
# ..      ...       ...     ...            ...     ...   ...      ...    ...
# 66       67       p67     사토리       올드 월드 체다    하드치즈  자연치즈       체다  11500
# 67       68       p68     라퀘유         푸름 당베르    연성치즈  자연치즈     블루치즈  12500
# 68       69       p69   그랑도르즈      베이크드 까망베르   소프트치즈  자연치즈     까망베르  11900
# 69       70       p70  퀘소로시난테  만체고 블랙 트러플 치즈    하드치즈  자연치즈      만체고  12500
# 70       71       p71     라퀘유        블루 도베르뉴  세미하드치즈  자연치즈     블루치즈  10200
#
#                         content  \
# 0        버터처럼 부드러운 크림이 들어있는 생치즈
# ...

# %%
df
# Out:
#     ranking cheese_id   brand           name texture types category  price  \
# 0         1        p1  벨지오이오소         부라타 치즈   후레쉬치즈  자연치즈      부라타  14900
# 1         2        p2    프란시아        모짜렐라 카우   후레쉬치즈  자연치즈     모짜렐라   3870
# 2         3        p3     브렐렛        모짜렐라 카우   후레쉬치즈  자연치즈     모짜렐라   3990
# 3         4        p4    카스텔로      덴마크 브리 치즈   소프트치즈  자연치즈       브리   4165
# 4         5        p5     브리미           보코치니   후레쉬치즈  자연치즈     모짜렐라   6800
# ..      ...       ...     ...            ...     ...   ...      ...    ...
# 66       67       p67     사토리       올드 월드 체다    하드치즈  자연치즈       체다  11500
# 67       68       p68     라퀘유         푸름 당베르    연성치즈  자연치즈     블루치즈  12500
# 68       69       p69   그랑도르즈      베이크드 까망베르   소프트치즈  자연치즈     까망베르  11900
# 69       70       p70  퀘소로시난테  만체고 블랙 트러플 치즈    하드치즈  자연치즈      만체고  12500
# 70       71       p71     라퀘유        블루 도베르뉴  세미하드치즈  자연치즈     블루치즈  10200
#
#                         content  \
# 0        버터처럼 부드러운 크림이 들어있는 생치즈
# ...

# %%
data = [
    ["사,과", "바나나"],
    ["감자", "옥,수,수"],
    ["콜라", "사,이다"]
]

columns = ["음식1", "음식2"]

df2 = pd.DataFrame(data=data, columns=columns)

print(df2)
# Out:
#    음식1    음식2
# 0  사,과    바나나
# 1   감자  옥,수,수
# 2   콜라   사,이다

# %%
def remove_comma(x):
    return x.replace(',', '')

df2['음식2'] = df2['음식2'].apply(remove_comma)
print(df2)
print(df2.dtypes)
# Out:
#    음식1  음식2
# 0  사,과  바나나
# 1   감자  옥수수
# 2   콜라  사이다
# 음식1    object
# 음식2    object
# dtype: object
